# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, TimestampType
customers_schema = StructType([
    StructField("customer_id", IntegerType(), True),
    StructField("first_name", StringType(), True),
    StructField("last_name", StringType(), True),
    StructField("email", StringType(), True)
])


messages_schema = StructType([
    StructField("message_id", IntegerType(), True),
    StructField("customer_id", IntegerType(), True),
    StructField("message", StringType(), True),
    StructField("timestamp", TimestampType(), True)
])
#.schema(schema)\

def stream_mount_into_table(mount_path,table_name,schema):
    streaming_df = spark.readStream\
                    .format("cloudFiles")\
                    .option('cloudFiles.format', 'csv')\
                    .schema(schema)\
                    .load(mount_path)\
                    .writeStream\
                    .option("checkpointLocation",f"/tmp/checkpoint/{table_name}")\
                    .table(table_name)

customers_path = 'dbfs:/mnt/customers/'
customers_table = 'customers_bronze3'
messages_path = 'dbfs:/mnt/messages/'
messages_table = 'messages_bronze3'
stream_mount_into_table(customers_path,customers_table,customers_schema)
stream_mount_into_table(messages_path,messages_table,messages_schema)

# %%
# %sql
CREATE OR REFRESH LIVE TABLE customer_messages_silver AS
SELECT *,
CASE WHEN lower(message) LIKE '%warning%' THEN 'Warning'
     WHEN lower(message) LIKE '%restored%' THEN 'Restored'
     WHEN lower(message) LIKE '%outage%' THEN 'Outage'
     WHEN lower(message) LIKE '%estimate%' THEN 'Estimate'
     ELSE NULL
END AS status_update,
to_date(timestamp) as date
FROM
(SELECT * FROM customers_bronze3
LEFT JOIN messages_bronze3
using (customer_id))
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>customer_messages_silver</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>first_name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>last_name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>email</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>message_id</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>message</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>timestamp</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>status_update</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>date</td>
#    <td>date</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1475617488785413#joblist/pipelines/create?initialSource=%2FUsers%2Fjkgprofessional%40gmail.com%2Ffull_stream&redirectNotebookId=2451849458635677">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
# %sql
CREATE OR REFRESH LIVE TABLE sent_messages_gold AS
SELECT date, customer_id, count(message_id) as messages_sent
FROM customers_messages_silver
where date is not null
group by 1,2
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>sent_messages_gold</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>date</td>
#    <td>date</td>
# </tr>
#
# <tr>
#    <td>customer_id</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>messages_sent</td>
#    <td>bigint</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=1475617488785413#joblist/pipelines/create?initialSource=%2FUsers%2Fjkgprofessional%40gmail.com%2Ffull_stream&redirectNotebookId=2451849458635677">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
